# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ml_meta_df = pd.read_csv("").sort_values(by="rate", ascending=True)
ml_meta_df
# Out:
#     rate  test_mae_all  test_mae_high  test_mae_low  test_mae_med  \
# 21   0.0      0.686860       0.672745      0.769809      0.706180
# 11   0.0      0.686860       0.673161      0.770091      0.706693
# 20   0.1      0.698358       0.681804      0.806149      0.721682
# 10   0.1      0.698358       0.682227      0.805974      0.721992
# 9    0.2      0.691368       0.675579      0.785206      0.715351
# 19   0.2      0.691368       0.675164      0.783075      0.714392
# 8    0.3      0.683819       0.664128      0.777932      0.704949
# 18   0.3      0.683819       0.663796      0.776203      0.702779
# 7    0.4      0.692656       0.676647      0.775522      0.710111
# 17   0.4      0.692656       0.676072      0.776053      0.708162
# 6    0.5      0.704719       0.687944      0.802198      0.720631
# 16   0.5      0.704719       0.687387      0.796917      0.716564
# 5    0.6      0.725255       0.702852      0.812794      0.738997
# ...
